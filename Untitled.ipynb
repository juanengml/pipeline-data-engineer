# %% [markdown]
# ## Ingestão de dados no Banco

# %% [markdown]
# ### Install dependencias

# %%
# !sudo apt-get install libmysqlclient-dev --yes
# Out:
# [sudo] password for jovyan:

# %%
# !pip install dataset console-logging mysqlclient dataset --no-cache-dir
# Out:
# Requirement already satisfied: dataset in /opt/conda/lib/python3.9/site-packages (1.5.1)
# Collecting console-logging
#   Downloading console_logging-0.0.5.0-py2.py3-none-any.whl (5.3 kB)
# Collecting mysqlclient
#   Downloading mysqlclient-2.1.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 7.0 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_05a648a9a3ce401997f0ba14492723b0/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_05a648a9a3ce401997f0ba14492723b0/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-iv_st5rt
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_05a648a9a3ce401997f0ba14492723b0/
#   Complete output (15 lines):
#   mysql_config --version
#   /bin/sh: 1: mysql_config: not found
#   mariadb_config --version
#   /bin/sh: 1: mariadb_config: not found
#   mysql_config --libs
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_05a648a9a3ce401997f0ba14492723b0/setup.py", line 15, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_05a648a9a3ce401997f0ba14492723b0/setup_posix.py", line 70, in get_config
#       libs = mysql_config("libs")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_05a648a9a3ce401997f0ba14492723b0/setup_posix.py", line 31, in mysql_config
#       raise OSError("{} not found".format(_mysql_config_path))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/de/79/d02be3cb942afda6c99ca207858847572e38146eb73a7c4bfe3bdf154626/mysqlclient-2.1.0.tar.gz#sha256=973235686f1b720536d417bf0a0d39b4ab3d5086b2b6ad5e6752393428c02b12 (from https://pypi.org/simple/mysqlclient/) (requires-python:>=3.5). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mysqlclient-2.0.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 8.6 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_347cc059c78d43129152962b4d89a01d/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_347cc059c78d43129152962b4d89a01d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-ia8rravb
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_347cc059c78d43129152962b4d89a01d/
#   Complete output (15 lines):
#   mysql_config --version
#   /bin/sh: 1: mysql_config: not found
#   mariadb_config --version
#   /bin/sh: 1: mariadb_config: not found
#   mysql_config --libs
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_347cc059c78d43129152962b4d89a01d/setup.py", line 15, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_347cc059c78d43129152962b4d89a01d/setup_posix.py", line 70, in get_config
#       libs = mysql_config("libs")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_347cc059c78d43129152962b4d89a01d/setup_posix.py", line 31, in mysql_config
#       raise OSError("{} not found".format(_mysql_config_path))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3c/df/59cd2fa5e48d0804d213bdcb1acb4d08c403b61c7ff7ed4dd4a6a2deb3f7/mysqlclient-2.0.3.tar.gz#sha256=f6ebea7c008f155baeefe16c56cd3ee6239f7a5a9ae42396c2f1860f08a7c432 (from https://pypi.org/simple/mysqlclient/) (requires-python:>=3.5). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mysqlclient-2.0.2.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 8.3 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_033d125269ff42c3b1e4c37f52e45700/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_033d125269ff42c3b1e4c37f52e45700/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-_x3injfm
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_033d125269ff42c3b1e4c37f52e45700/
#   Complete output (12 lines):
#   /bin/sh: 1: mysql_config: not found
#   /bin/sh: 1: mariadb_config: not found
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_033d125269ff42c3b1e4c37f52e45700/setup.py", line 15, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_033d125269ff42c3b1e4c37f52e45700/setup_posix.py", line 65, in get_config
#       libs = mysql_config("libs")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_033d125269ff42c3b1e4c37f52e45700/setup_posix.py", line 31, in mysql_config
#       raise OSError("{} not found".format(_mysql_config_path))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/0e/68/f79de0e0fcdb041783124b825771e0ba6a3d0893b7b4c4735f130e42af47/mysqlclient-2.0.2.tar.gz#sha256=8df057b08fc27d8f7106bfa997d0a21e2acef017f905f06d6fb0aa6a20d4d2b2 (from https://pypi.org/simple/mysqlclient/) (requires-python:>=3.5). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mysqlclient-2.0.1.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 8.6 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_7fbdf00d3d0a4d40a06593dcff4fed9b/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_7fbdf00d3d0a4d40a06593dcff4fed9b/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-1ssun8r0
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_7fbdf00d3d0a4d40a06593dcff4fed9b/
#   Complete output (12 lines):
#   /bin/sh: 1: mysql_config: not found
#   /bin/sh: 1: mariadb_config: not found
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_7fbdf00d3d0a4d40a06593dcff4fed9b/setup.py", line 15, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_7fbdf00d3d0a4d40a06593dcff4fed9b/setup_posix.py", line 65, in get_config
#       libs = mysql_config("libs")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_7fbdf00d3d0a4d40a06593dcff4fed9b/setup_posix.py", line 31, in mysql_config
#       raise OSError("{} not found".format(_mysql_config_path))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a5/e1/e5f2b231c05dc51d9d87fa5066f90d1405345c54b14b0b11a1c859020f21/mysqlclient-2.0.1.tar.gz#sha256=fb2f75aea14722390d2d8ddf384ad99da708c707a96656210a7be8af20a2c5e5 (from https://pypi.org/simple/mysqlclient/) (requires-python:>=3.5). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mysqlclient-2.0.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 7.7 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_bef4edf7d1334b1f81f0c3ccbfb90359/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_bef4edf7d1334b1f81f0c3ccbfb90359/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-kv1a9civ
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_bef4edf7d1334b1f81f0c3ccbfb90359/
#   Complete output (12 lines):
#   /bin/sh: 1: mysql_config: not found
#   /bin/sh: 1: mariadb_config: not found
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_bef4edf7d1334b1f81f0c3ccbfb90359/setup.py", line 15, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_bef4edf7d1334b1f81f0c3ccbfb90359/setup_posix.py", line 65, in get_config
#       libs = mysql_config("libs")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_bef4edf7d1334b1f81f0c3ccbfb90359/setup_posix.py", line 31, in mysql_config
#       raise OSError("{} not found".format(_mysql_config_path))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ca/cf/dd8124bf8b3d2ae465db9c8ce35c51650c31784b095f41faf6f8cad987a0/mysqlclient-2.0.0.tar.gz#sha256=201dfcc2a3c8a0859ea399947f1af8abe74b706beba0ebac149180d9d7b0f6e8 (from https://pypi.org/simple/mysqlclient/) (requires-python:>=3.5). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mysqlclient-1.4.6.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 7.4 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_703b7ec5194e4b6c89d4e22bb1a18e77/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_703b7ec5194e4b6c89d4e22bb1a18e77/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-giqkr9wp
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_703b7ec5194e4b6c89d4e22bb1a18e77/
#   Complete output (12 lines):
#   /bin/sh: 1: mysql_config: not found
#   /bin/sh: 1: mariadb_config: not found
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_703b7ec5194e4b6c89d4e22bb1a18e77/setup.py", line 16, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_703b7ec5194e4b6c89d4e22bb1a18e77/setup_posix.py", line 61, in get_config
#       libs = mysql_config("libs")
#     File "/tmp/pip-install-x8k336cn/mysqlclient

#   Complete output (10 lines):
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_7c37399df37d47178f36f593dcaa6fec/setup.py", line 17, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_7c37399df37d47178f36f593dcaa6fec/setup_posix.py", line 47, in get_config
#       libs = mysql_config("libs_r")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_7c37399df37d47178f36f593dcaa6fec/setup_posix.py", line 29, in mysql_config
#       raise EnvironmentError("%s not found" % (mysql_config.path,))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/17/d9/03b08e6a033401335b720806b87596aee8d7f7aa87539713238905c4a8d1/mysqlclient-1.3.4.tar.gz#sha256=a0263383f8ac33ad12d68dc61fa8ccbee41244ce916287c6cee71bf8aea82c5c (from https://pypi.org/simple/mysqlclient/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mysqlclient-1.3.3.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 2.4 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_a8964949f9f44130a5ad72cf36fb632b/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_a8964949f9f44130a5ad72cf36fb632b/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-s61n1_50
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_a8964949f9f44130a5ad72cf36fb632b/
#   Complete output (10 lines):
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_a8964949f9f44130a5ad72cf36fb632b/setup.py", line 17, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_a8964949f9f44130a5ad72cf36fb632b/setup_posix.py", line 47, in get_config
#       libs = mysql_config("libs_r")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_a8964949f9f44130a5ad72cf36fb632b/setup_posix.py", line 29, in mysql_config
#       raise EnvironmentError("%s not found" % (mysql_config.path,))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/26/53/c575db342bfca0213c9243ed2642bfadcd420b18d2f477dc812543e3d83a/mysqlclient-1.3.3.tar.gz#sha256=0f0887882d71bf2a079d9724d9323053cfbee8ab2dcfc989daf97d7ce5be9af9 (from https://pypi.org/simple/mysqlclient/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mysqlclient-1.3.2.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 8.9 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_6b80cb5b89f44503b8cf3f9c7e0c071d/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_6b80cb5b89f44503b8cf3f9c7e0c071d/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-k7oxdulu
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_6b80cb5b89f44503b8cf3f9c7e0c071d/
#   Complete output (10 lines):
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_6b80cb5b89f44503b8cf3f9c7e0c071d/setup.py", line 17, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_6b80cb5b89f44503b8cf3f9c7e0c071d/setup_posix.py", line 47, in get_config
#       libs = mysql_config("libs_r")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_6b80cb5b89f44503b8cf3f9c7e0c071d/setup_posix.py", line 29, in mysql_config
#       raise EnvironmentError("%s not found" % (mysql_config.path,))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2d/df/5440ee86bbb248325cdd6e1fc9cbbba365018a0d2d57f673610e020e6b1d/mysqlclient-1.3.2.tar.gz#sha256=e44025830501b9f70f8c2fe8eeff66f0df2df198802f7295801dac199b8236ef (from https://pypi.org/simple/mysqlclient/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mysqlclient-1.3.1.tar.gz (76 kB)
#      |████████████████████████████████| 76 kB 5.2 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_2e14821d33424fa385302efc71360276/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_2e14821d33424fa385302efc71360276/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-hyhtj8p3
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_2e14821d33424fa385302efc71360276/
#   Complete output (10 lines):
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_2e14821d33424fa385302efc71360276/setup.py", line 17, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_2e14821d33424fa385302efc71360276/setup_posix.py", line 47, in get_config
#       libs = mysql_config("libs_r")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_2e14821d33424fa385302efc71360276/setup_posix.py", line 29, in mysql_config
#       raise EnvironmentError("%s not found" % (mysql_config.path,))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6b/ba/4729d99e85a0a35bb46d55500570de05b4af10431cef174b6da9f58a0e50/mysqlclient-1.3.1.tar.gz#sha256=3549e8a61f10c8cd8eac6581d3f44d0594f535fb7b29e6090db3a0bc547b25ad (from https://pypi.org/simple/mysqlclient/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading mysqlclient-1.3.0.tar.gz (76 kB)
#      |████████████████████████████████| 76 kB 7.7 MB/s
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python3.9 -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-x8k336cn/mysqlclient_d8c88c029c8c4b2c878ad38ae612f9d7/setup.py'"'"'; __file__='"'"'/tmp/pip-install-x8k336cn/mysqlclient_d8c88c029c8c4b2c878ad38ae612f9d7/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-j73fa0ad
#        cwd: /tmp/pip-install-x8k336cn/mysqlclient_d8c88c029c8c4b2c878ad38ae612f9d7/
#   Complete output (10 lines):
#   /bin/sh: 1: mysql_config: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-x8k336cn/mysqlclient_d8c88c029c8c4b2c878ad38ae612f9d7/setup.py", line 17, in <module>
#       metadata, options = get_config()
#     File "/tmp/pip-install-x8k336cn/mysqlclient_d8c88c029c8c4b2c878ad38ae612f9d7/setup_posix.py", line 47, in get_config
#       libs = mysql_config("libs_r")
#     File "/tmp/pip-install-x8k336cn/mysqlclient_d8c88c029c8c4b2c878ad38ae612f9d7/setup_posix.py", line 29, in mysql_config
#       raise EnvironmentError("%s not found" % (mysql_config.path,))
#   OSError: mysql_config not found
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6a/91/bdfe808fb5dc99a5f65833b370818161b77ef6d1e19b488e4c146ab615aa/mysqlclient-1.3.0.tar.gz#sha256=06eb5664e3738b283ea2262ee60ed83192e898f019cc7ff251f4d05a564ab3b7 (from https://pypi.org/simple/mysqlclient/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ERROR: Could not find a version that satisfies the requirement mysqlclient (from versions: 1.3.0, 1.3.1, 1.3.2, 1.3.3, 1.3.4, 1.3.5, 1.3.6, 1.3.7, 1.3.8, 1.3.9, 1.3.10, 1.3.11rc1, 1.3.11, 1.3.12, 1.3.13, 1.3.14, 1.4.0rc1, 1.4.0rc2, 1.4.0rc3, 1.4.0, 1.4.1, 1.4.2, 1.4.2.post1, 1.4.3, 1.4.4, 1.4.5, 1.4.6, 2.0.0, 2.0.1, 2.0.2, 2.0.3, 2.1.0rc1, 2.1.0)
# ERROR: No matching distribution found for mysqlclient

# %%
import dataset

db = dataset.connect('mysql://user:password@localhost/mydatabase')

# %%
# Out:
# Collecting dataset
#   Downloading dataset-1.5.1-py2.py3-none-any.whl (18 kB)
# Collecting banal>=1.0.1
#   Downloading banal-1.0.6-py2.py3-none-any.whl (6.1 kB)
# Requirement already satisfied: alembic>=0.6.2 in /opt/conda/lib/python3.9/site-packages (from dataset) (1.7.4)
# Requirement already satisfied: sqlalchemy>=1.3.2 in /opt/conda/lib/python3.9/site-packages (from dataset) (1.4.26)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.9/site-packages (from alembic>=0.6.2->dataset) (1.1.5)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.9/site-packages (from sqlalchemy>=1.3.2->dataset) (1.1.2)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/conda/lib/python3.9/site-packages (from Mako->alembic>=0.6.2->dataset) (2.0.1)
# Installing collected packages: banal, dataset
# Successfully installed banal-1.0.6 dataset-1.5.1

# %%
john
# Out:
# OrderedDict([('id', 1), ('name', 'John Doe'), ('age', 37), ('gender', None)])
